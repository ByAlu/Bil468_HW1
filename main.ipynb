# %%
import TemplateMatcher

matcher = TemplateMatcher.TemplateMatcher()

thresholds = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
method_thresholds = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9]

results = matcher.train(thresholds, method_thresholds)

print(results)

result = matcher.evaluate()
print("---------------------------------------------")

print(result)
# Out:
# c:\Users\alibe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1879: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       4
#       5 thresholds = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
#       6 method_thresholds = [0.3, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
#       7
# ----> 8 results = matcher.train(thresholds, method_thresholds)
#       9
#      10 print(results)
#      11
#
# File c:\DEV\Bil468_HW1\TemplateMatcher.py:108, in TemplateMatcher.train(self, thresholds, method_thresholds)
#     106 for(template_name, template_list) in self.templates.items():
#     107     for template in template_list:
# --> 108         val, loc = self.apply_template_matching(image, template)
#     110         if self.compare_results(best_intersection[0], val):
#     111             best_intersection = [val,loc,template.shape]
#
# File c:\DEV\Bil468_HW1\TemplateMatcher.py:48, in TemplateMatcher.apply_template_matching(self_, image, template)
#      44 def apply_template_matching(self_,image, template):
#      45     # imageye önişlem
# ---> 48     result = cv2.matchTemplate(image, template, self_._method)
#      49     min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
#      51     if self_._method == cv2.TM_CCOEFF_NORMED or self_._method == cv2.TM_CCORR_NORMED:
#
# KeyboardInterrupt:
